# %%
import pandas as pd
import os

# %%
tmp = '/XYFS01/HDD_POOL/gzfezx_shhli/gzfezx_shhlixy_2/BIGDATA2/gzfezx_shhli_2/USER/luozhenyu/20260807_RRBS/hsa/output/01.fq2methRatio/BIG_RRBS_000009/BIG_RRBS_000009_sum_info.txt'
os.path.splitext(os.path.basename(tmp.rstrip('_sum_info.txt')))[0]
# Out:
# 'BIG_RRBS_000009'
